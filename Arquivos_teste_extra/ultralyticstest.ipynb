# %% [markdown]
# <a href="https://colab.research.google.com/github/rlrocha90/TP555_projeto_final/blob/main/Arquivos_teste_extra/ultralyticstest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics --quiet

# %%
# %cd /content
# Out:
# /content

# %%
from ultralytics import YOLO

# Load a model
model_orig = YOLO('yolov8n.pt')  # load an official detection model
#model = YOLO('yolov8n-seg.pt')  # load an official segmentation model
#model = YOLO('path/to/best.pt')  # load a custom model

# %%
# Track with the model
results_orig = model_orig.track(source="/content/BoatSideView.mp4", conf=0.5, show=True, tracker="botsort.yaml")
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1177) /content/BoatSideView.mp4: 384x640 (no detections), 210.5ms
# video 1/1 (2/1177) /content/BoatSideView.mp4: 384x640 (no detections), 160.0ms
# video 1/1 (3/1177) /content/BoatSideView.mp4: 384x640 (no detections), 137.6ms
# video 1/1 (4/1177) /content/BoatSideView.mp4: 384x640 (no detections), 137.9ms
# ...

# %%
from google.colab.patches import cv2_imshow

boxes = results_orig[603].boxes
box = boxes[0]
box.xyxy

res_plot = results_orig[603].plot()
cv2_imshow(res_plot)
# Out:
# <PIL.Image.Image image mode=RGB size=852x480 at 0x79C90CA32FE0>

# %%
model_best = YOLO('yolov8n_best.pt')  # load an official detection model

# %%
# Track with the model
results_best = model_best.track(source="/content/BoatSideView.mp4", conf=0.5, show=True, tracker="botsort.yaml")
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1177) /content/BoatSideView.mp4: 384x640 (no detections), 216.3ms
# video 1/1 (2/1177) /content/BoatSideView.mp4: 384x640 (no detections), 139.3ms
# video 1/1 (3/1177) /content/BoatSideView.mp4: 384x640 (no detections), 134.4ms
# video 1/1 (4/1177) /content/BoatSideView.mp4: 384x640 (no detections), 136.8ms
# ...

# %%
from google.colab.patches import cv2_imshow

boxes = results_best[1167].boxes
box = boxes[0]
box.xyxy

res_plot = results_best[1167].plot()
cv2_imshow(res_plot)
# Out:
# <PIL.Image.Image image mode=RGB size=852x480 at 0x79C90B9BA110>

# %%
from ultralytics.vit.sam.amg import Any
from ultralytics.vit.sam.predict import BasePredictor

result2 = model.predict("/content/Teste1.mp4", stream=False)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/645) /content/Teste1.mp4: 384x640 2 boats, 288.8ms
# video 1/1 (2/645) /content/Teste1.mp4: 384x640 2 boats, 284.7ms
# video 1/1 (3/645) /content/Teste1.mp4: 384x640 2 boats, 269.2ms
# video 1/1 (4/645) /content/Teste1.mp4: 384x640 2 boats, 271.3ms
# video 1/1 (5/645) /content/Teste1.mp4: 384x640 2 boats, 280.4ms
# video 1/1 (6/645) /content/Teste1.mp4: 384x640 2 boats, 265.1ms
# ...

# %%
a = BasePredictor()
a.save_preds('/content/Teste1.mp4', Any, '/content')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-e94703590727> in <cell line: 2>()
#       1 a = BasePredictor()
# ----> 2 a.save_preds('/content/Teste1.mp4', Any, '/content')
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/predictor.py in save_preds(self, vid_cap, idx, save_path)
#     317         im0 = self.plotted_img
#     318         # Save imgs
# --> 319         if self.dataset.mode == 'image':
#     320             cv2.imwrite(save_path, im0)
#     321         else:  # 'video' or 'stream'
#
# AttributeError: 'NoneType' object has no attribute 'mode'
